# %%
#importing pandas libaries and sklearn datasets
import pandas as pd
from sklearn import datasets
import numpy as np

# %%
iris = datasets.load_iris()
iris_df = pd.DataFrame(iris.data)

#Creating feature columns 
column_names = iris.feature_names
iris_df.columns = column_names

# %%
#SPEARMAN'S. RANK CORRELATION.
iris_df.corr(method ='spearman')
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.166778           0.881898
# sepal width (cm)           -0.166778          1.000000          -0.309635
# petal length (cm)           0.881898         -0.309635           1.000000
# petal width (cm)            0.834289         -0.289032           0.937667
#
#                    petal width (cm)
# sepal length (cm)          0.834289
# sepal width (cm)          -0.289032
# petal length (cm)          0.937667
# petal width (cm)           1.000000

# %%
#Importing matplotlib libary
from matplotlib import pyplot as plt

# %% [markdown]
# <h1>Iris Data Visualization<h1>

# %%
plt.scatter(iris_df['sepal length (cm)'], iris.target)
plt.xlabel('sepal length (cm)')
plt.ylabel('target')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <h4>This plot shows the scatter plot of the target of the iris dataset against the sepal length (cm) feature of the data <h4>

# %%
plt.scatter(iris_df['sepal width (cm)'], iris.target)
plt.xlabel('sepal width (cm)')
plt.ylabel('target')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <h4>This plot shows the scatter plot of the target of the iris dataset against the sepal width (cm) feature of the data <h4>

# %%
plt.scatter(iris_df['petal length (cm)'], iris.target)
plt.xlabel('petal length (cm)')
plt.ylabel('target')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <h4>This plot shows the scatter plot of the target of the iris dataset against the petal length (cm) feature of the data <h4>

# %%
plt.scatter(iris_df['petal width (cm)'], iris.target)
plt.xlabel('petal width (cm)')
plt.ylabel('target')
plt.show()
# Out:
# <div id='6addef82-994a-4c1b-a92b-7d497f052715'></div>

# %% [markdown]
# <h4>This plot shows the scatter plot of the target of the iris dataset against the petal width (cm) feature of the data <h4>

# %%
#Normalizing the iris dataset using Zscore
def z_score(df):
    df.columns = [x + "_zscore" for x in df.columns.tolist()]
    return ((df - df.mean())/df.std(ddof=0))

print(z_score(iris_df))
# Out:
#      sepal length (cm)_zscore  sepal width (cm)_zscore  \
# 0                   -0.900681                 1.019004
# 1                   -1.143017                -0.131979
# 2                   -1.385353                 0.328414
# 3                   -1.506521                 0.098217
# 4                   -1.021849                 1.249201
# ..                        ...                      ...
# 145                  1.038005                -0.131979
# 146                  0.553333                -1.282963
# 147                  0.795669                -0.131979
# 148                  0.432165                 0.788808
# 149                  0.068662                -0.131979
#
#      petal length (cm)_zscore  petal width (cm)_zscore
# 0                   -1.340227                -1.315444
# 1                   -1.340227                -1.315444
# 2                   -1.397064                -1.315444
# 3                   -1.283389                -1.315444
# ...
